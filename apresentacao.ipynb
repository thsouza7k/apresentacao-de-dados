# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
base = pd.read_csv('train.csv')
base.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
base.info()
# presença de valores nulos na coluna 'Postal Code'
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
# Verificando os registros com Postal code vazio
base[base['Postal Code'].isnull()]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2234    2235  CA-2018-104066  05/12/2018  10/12/2018  Standard Class
# 5274    5275  CA-2016-162887  07/11/2016  09/11/2016    Second Class
# 8798    8799  US-2017-150140  06/04/2017  10/04/2017  Standard Class
# 9146    9147  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9147    9148  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9148    9149  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9386    9387  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9387    9388  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9388    9389  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9389    9390  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9741    9742  CA-2016-117086  08/11/2016  12/11/2016  Standard Class
#
#      Customer ID     Customer Name      Segment        Country        City  \
# ...

# %%
# Verificando se existe outros registro com City == 'Burlington' e se possuem Postal Code 
base[(base.City == 'Burlington') & (base.State == 'Vermont') & (base['Postal Code']).notnull()]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales]
# Index: []

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Atribuindo o postal code = 05401 
base.loc[(base.City == 'Burlington') & (base.State == 'Vermont') & (base['Postal Code']).isnull(), "Postal Code"] = 5401
base.loc[(base.City == 'Burlington') & (base.State == 'Vermont')]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2234    2235  CA-2018-104066  05/12/2018  10/12/2018  Standard Class
# 5274    5275  CA-2016-162887  07/11/2016  09/11/2016    Second Class
# 8798    8799  US-2017-150140  06/04/2017  10/04/2017  Standard Class
# 9146    9147  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9147    9148  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9148    9149  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9386    9387  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9387    9388  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9388    9389  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9389    9390  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9741    9742  CA-2016-117086  08/11/2016  12/11/2016  Standard Class
#
#      Customer ID     Customer Name      Segment        Country        City  \
# ...

# %%
# Tratando as colunas de datas que estão com Dtype = object 
import datetime as dt
base["Order Date"] = pd.to_datetime(base["Order Date"], format="%d/%m/%Y")
base["Ship Date"] = pd.to_datetime(base["Ship Date"], format="%d/%m/%Y")

# %%
base["Order Date"].min()
# Out:
# Timestamp('2015-01-03 00:00:00')

# %%
base["Order Date"].max()
# Out:
# Timestamp('2018-12-30 00:00:00')

# %%
# Criando uma coluna para separar o ano
base['Ano'] = base['Order Date'].dt.year

# %% [markdown]
# ###  Visualizando vendas por ano

# %%
base.groupby("Ano")["Sales"].sum()
# Out:
# Ano
# 2015    479856.2081
# 2016    459436.0054
# 2017    600192.5500
# 2018    722052.0192
# Name: Sales, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(9,6))

soma_ano = base.groupby("Ano")["Sales"].sum()

ax.bar(soma_ano.index , soma_ano.values, linewidth=2, color="#84ba5b");
ax.set_title("VENDAS POR ANO",
             fontsize= 14,
             fontweight= "bold",
             color= "#84ba5b");
ax.xaxis.set_ticks([2015,2016,2017,2018]);
ax.tick_params(axis='x', labelsize=12)

for i in range(len(soma_ano.index)):
            ax.annotate('{: ,.0f}'.format(soma_ano.values[i]), (soma_ano.index[i], soma_ano.values[i]),ha="center", xytext=(0,7), textcoords="offset points", fontweight="bold")
ax.yaxis.set_visible(False)
ax.spines.left.set_visible(False)
ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)


plt.show()

# %% [markdown]
# ###  Visualizando vendas por mês

# %%
# criando coluna mês
base["Mes"] = base["Order Date"].dt.month
base.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-11-08 2017-11-11  Second Class    CG-12520
# 1       2  CA-2017-152156 2017-11-08 2017-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City     State  Postal Code  \
# 0   Claire Gute  Consumer  United States  Henderson  Kentucky      42420.0
# 1   Claire Gute  Consumer  United States  Henderson  Kentucky      42420.0
#
#   Region       Product ID   Category Sub-Category  \
# 0  South  FUR-BO-10001798  Furniture    Bookcases
# 1  South  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales   Ano  Mes
# 0                  Bush Somerset Collection Bookcase  261.96  2017   11
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94  2017   11

# %%
soma_mes = base.groupby(["Mes", "Ano"])["Sales"].sum()
soma_mes.head()
# Out:
# Mes  Ano
# 1    2015    14205.7070
#      2016    18066.9576
#      2017    18542.4910
#      2018    43476.4740
# 2    2015     4519.8920
# Name: Sales, dtype: float64

# %%
# Transformando os indices em colunas
soma_mes = soma_mes.reset_index()
soma_mes.head()
# Out:
#    Mes   Ano       Sales
# 0    1  2015  14205.7070
# 1    1  2016  18066.9576
# 2    1  2017  18542.4910
# 3    1  2018  43476.4740
# 4    2  2015   4519.8920

# %%
fig, ax = plt.subplots(figsize=(16,4))
w = 0.2
ax.bar(soma_mes[soma_mes.Ano == 2015].Mes.values -w-w/2, soma_mes[soma_mes.Ano == 2015].Sales.values,
                                color="#00c698", label='2015',width=w )
ax.bar(soma_mes[soma_mes.Ano == 2016].Mes.values-w/2 , soma_mes[soma_mes.Ano == 2016].Sales.values,
                                color='#00a9b5', label='2016',width=w)
ax.bar(soma_mes[soma_mes.Ano == 2017].Mes.values+w/2 , soma_mes[soma_mes.Ano == 2017].Sales.values,
                                color="#008ac5", label='2017',width=w )
ax.bar(soma_mes[soma_mes.Ano == 2018].Mes.values+w+w/2 , soma_mes[soma_mes.Ano == 2018].Sales.values,
                                color="#0069c0", label="2018",width=w )
ax.legend()
for i in range(0,12):
            ax.annotate('{: ,.0f}k'.format(soma_mes[soma_mes.Ano == 2018].Sales.values[i]/1000), 
                        (soma_mes[soma_mes.Ano == 2018].Mes.values[i]+w+w/2, soma_mes[soma_mes.Ano == 2018].Sales.values[i]),
                        ha="center", 
                        xytext=(3,5), 
                        textcoords="offset points", 
                        color="#0069c0",
                        fontweight="bold")
ax.set_yticks(np.array([0, 100000]))
ax.yaxis.set_visible(False)
ax.spines.top.set_visible(False)
ax.spines.right.set_visible(False)
ax.spines.left.set_visible(False) 
ax.xaxis.set_ticks(np.arange(1,13))
ax.set_xticklabels(['Jan','Fev','Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez'])
plt.show()

# %% [markdown]
# #### Qual categoria vendeu mais ?

# %%
base.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-11-08 2017-11-11  Second Class    CG-12520
# 1       2  CA-2017-152156 2017-11-08 2017-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City     State  Postal Code  \
# 0   Claire Gute  Consumer  United States  Henderson  Kentucky      42420.0
# 1   Claire Gute  Consumer  United States  Henderson  Kentucky      42420.0
#
#   Region       Product ID   Category Sub-Category  \
# 0  South  FUR-BO-10001798  Furniture    Bookcases
# 1  South  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales   Ano  Mes
# 0                  Bush Somerset Collection Bookcase  261.96  2017   11
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94  2017   11

# %%
categoria = base.groupby(["Category", "Ano"])["Sales"].sum()

# %%
# transformando em um data frame para ser mais facil o trabalho
categoria = categoria.reset_index()
categoria
# Out:
#            Category   Ano        Sales
# 0         Furniture  2015  156477.8811
# 1         Furniture  2016  164053.8674
# 2         Furniture  2017  195813.0400
# 3         Furniture  2018  212313.7872
# 4   Office Supplies  2015  149512.8200
# 5   Office Supplies  2016  133124.4070
# 6   Office Supplies  2017  182417.5660
# 7   Office Supplies  2018  240367.5410
# 8        Technology  2015  173865.5070
# 9        Technology  2016  162257.7310
# 10       Technology  2017  221961.9440
# 11       Technology  2018  269370.6910

# %%
fig, ax = plt.subplots(figsize=(16,4))
w = 0.2
ax.bar(categoria[categoria.Category == 'Furniture'].Ano.values-w, 
       categoria[categoria.Category == 'Furniture'].Sales.values,
                                color="#00c698", label='Furniture',width=w )
ax.bar(categoria[categoria.Category == 'Office Supplies'].Ano.values, 
       categoria[categoria.Category == 'Office Supplies'].Sales.values,
                                color="#00a9b5", label='Office Supplies',width=w )
ax.bar(categoria[categoria.Category == 'Technology'].Ano.values+w, 
       categoria[categoria.Category == 'Technology'].Sales.values,
                                color="#008ac5", label='Technology',width=w )

for i in range(0,4):
            ax.annotate('{: ,.0f}k'.format(categoria[categoria.Category == 'Furniture'].Sales.values[i]/1000), 
                        (categoria[categoria.Category == 'Furniture'].Ano.values[i]-w, categoria[categoria.Category == 'Furniture'].Sales.values[i]),
                        ha="center", 
                        xytext=(0,5), 
                        textcoords="offset points", 
                        color="#00c698",
                        fontweight="bold")
            ax.annotate('{: ,.0f}k'.format(categoria[categoria.Category == 'Office Supplies'].Sales.values[i]/1000), 
                        (categoria[categoria.Category == 'Office Supplies'].Ano.values[i], categoria[categoria.Category == 'Office Supplies'].Sales.values[i]),
                        ha="center", 
                        xytext=(0,5), 
                        textcoords="offset points", 
                        color="#00c698",
                        fontweight="bold")
            ax.annotate('{: ,.0f}k'.format(categoria[categoria.Category == 'Technology'].Sales.values[i]/1000), 
                        (categoria[categoria.Category == 'Technology'].Ano.values[i]+w, categoria[categoria.Category == 'Technology'].Sales.values[i]),
                        ha="center", 
                        xytext=(0,5), 
                        textcoords="offset points", 
                        color="#00c698",
                        fontweight="bold")
            
ax.set_yticks(np.array([0,350000]))
ax.yaxis.set_visible(False)
ax.set_title("VENDAS POR ANO DE CADA CATEGORIA")

ax.spines.top.set_visible(False)
ax.spines.right.set_visible(False)
ax.spines.left.set_visible(False) 
ax.xaxis.set_ticks([2015,2016,2017,2018]);
ax.tick_params(axis='x', labelsize=10)

ax.legend()
plt.show()

# %% [markdown]
# #### Qual item mais vendido?

# %%
itens=base.groupby("Product Name")["Sales"].sum()
itens = itens.reset_index()
itens = itens.sort_values("Sales", ascending=False)

# %%
# Top 10 itens
n = 10
top_n_itens = itens.head(n)
top_n_itens
# Out:
#                                           Product Name      Sales
# 404              Canon imageCLASS 2200 Advanced Copier  61599.824
# 649  Fellowes PB500 Electric Punch Plastic Comb Bin...  27453.384
# 444  Cisco TelePresence System EX90 Videoconferenci...  22638.480
# 785       HON 5400 Series Task Chairs for Big and Tall  21870.576
# 685         GBC DocuBind TL300 Electric Binding System  19823.479
# 687   GBC Ibimaster 500 Manual ProClick Binding System  19024.500
# 804               Hewlett Packard LaserJet 3310 Copier  18839.686
# 786  HP Designjet T520 Inkjet Large Format Printer ...  18374.895
# 682          GBC DocuBind P400 Electric Binding System  17965.068
# 812        High Speed Automatic Electric Letter Opener  17030.312

# %%
fig, ax =plt.subplots(figsize=(10,9))

ax.barh(top_n_itens['Product Name'].values, #valor de y
            top_n_itens['Sales'].values,
            align='center'
        )
for i in range(0,n):
            ax.annotate('{: ,.0f}k'.format(top_n_itens['Sales'].values[i]/1000), 
                        (top_n_itens['Sales'].values[i], i ),
                        ha="center", 
                        va="top",
                        xytext=(-15,5), 
                        textcoords="offset points", 
                        color="#fff",
                        fontweight="bold")
            
ax.spines.top.set_visible(False)
ax.spines.right.set_visible(False)
ax.spines.left.set_visible(False) 
ax.spines.bottom.set_visible(False) 
ax.xaxis.set_visible(False)
ax.set_xticks(np.array([0,65000]))
ax.set_title("TOP 10 PRODUTOS DE TODOS OS TEMPOS")
ax.invert_yaxis()

# %% [markdown]
# ### Agrupando por item e ano

# %%
itens_ano=base.groupby(["Product Name", "Ano"])["Sales"].sum()
itens_ano = itens_ano.reset_index()
itens_ano
# Out:
#                                            Product Name   Ano    Sales
# 0     "While you Were Out" Message Book, One Form pe...  2018   25.228
# 1              #10 Gummed Flap White Envelopes, 100/Box  2016    6.608
# 2              #10 Gummed Flap White Envelopes, 100/Box  2017   24.780
# 3              #10 Gummed Flap White Envelopes, 100/Box  2018    9.912
# 4                         #10 Self-Seal White Envelopes  2017   86.502
# ...                                                 ...   ...      ...
# 5269  invisibleSHIELD by ZAGG Smudge-Free Screen Pro...  2018  205.086
# 5270                 netTALK DUO VoIP Telephone Service  2015  335.936
# 5271                 netTALK DUO VoIP Telephone Service  2016  230.956
# 5272                 netTALK DUO VoIP Telephone Service  2017  377.928
# 5273                 netTALK DUO VoIP Telephone Service  2018  167.968
#
# [5274 rows x 3 columns]

# %%
df_datas = pd.DataFrame([2018,2017,2016,2015])
df_datas.columns = ['Ano']
df_datas
# Out:
#     Ano
# 0  2018
# 1  2017
# 2  2016
# 3  2015

# %%
df_datas['uniao'] = 'unir'
itens['uniao'] = 'unir'

# %%
top_n_itens
# Out:
#                                           Product Name      Sales
# 404              Canon imageCLASS 2200 Advanced Copier  61599.824
# 649  Fellowes PB500 Electric Punch Plastic Comb Bin...  27453.384
# 444  Cisco TelePresence System EX90 Videoconferenci...  22638.480
# 785       HON 5400 Series Task Chairs for Big and Tall  21870.576
# 685         GBC DocuBind TL300 Electric Binding System  19823.479
# 687   GBC Ibimaster 500 Manual ProClick Binding System  19024.500
# 804               Hewlett Packard LaserJet 3310 Copier  18839.686
# 786  HP Designjet T520 Inkjet Large Format Printer ...  18374.895
# 682          GBC DocuBind P400 Electric Binding System  17965.068
# 812        High Speed Automatic Electric Letter Opener  17030.312

# %%
produto_ano = pd.merge(
    top_n_itens,
    df_datas,
    how='outer',
    on="uniao"
)
produto_ano.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14268\1212271076.py in ?()
# ----> 1 produto_ano = pd.merge(
#       2     top_n_itens,
#       3     df_datas,
#       4     how='outer',
#
# c:\Users\thsou\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     165             validate=validate,
#     166             copy=copy,
#     167         )
#     168     else:
# --> 169         op = _MergeOperation(
#     170             left_df,
#     171             right_df,
#     172             how=how,
#
# c:\Users\thsou\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     787             self.right_join_keys,
# ...

# %%
itens_ano_grafico = pd.merge(
    produto_ano,
    itens_ano,
    how='left',
    on=['Product Name', 'Ano']
)
itens_ano_grafico.head()
# Out:
#                                         Product Name    Sales_x uniao   Ano  \
# 0              Canon imageCLASS 2200 Advanced Copier  61599.824  unir  2018
# 1              Canon imageCLASS 2200 Advanced Copier  61599.824  unir  2017
# 2              Canon imageCLASS 2200 Advanced Copier  61599.824  unir  2016
# 3              Canon imageCLASS 2200 Advanced Copier  61599.824  unir  2015
# 4  Fellowes PB500 Electric Punch Plastic Comb Bin...  27453.384  unir  2018
#
#      Sales_y
# 0  35699.898
# 1  25899.926
# 2        NaN
# 3        NaN
# 4   7371.742

# %%
fig, ax =plt.subplots(figsize=(10,9))
#itens_ano_grafico[itens_ano_grafico.Ano == 2018]['Product Name'].values
# itens_ano_grafico[itens_ano_grafico.Ano == 2018].Sales_y.values - vendas ano a ano de cade item
hgt = 0.2
qtd_itens = len(top_n_itens)
ax.barh(np.arange(0, qtd_itens)-hgt-hgt/2, #valor de y
            itens_ano_grafico[itens_ano_grafico.Ano == 2018].Sales_y.values, #valor de x
            align='center', height=hgt,label='2018',
            color='#0059c0'
        )
ax.barh(np.arange(0, qtd_itens)-hgt/2, #valor de y
            itens_ano_grafico[itens_ano_grafico.Ano == 2017].Sales_y.values, #valor de x
            align='center', height=hgt,label='2017',
             color='#008ac5'
        )
ax.barh(np.arange(0, qtd_itens)+hgt/2, #valor de y
            itens_ano_grafico[itens_ano_grafico.Ano == 2016].Sales_y.values, #valor de x
            align='center', height=hgt,label='2016',
            color='#00a9b5'
        )
ax.barh(np.arange(0, qtd_itens)+hgt+hgt/2, #valor de y
            itens_ano_grafico[itens_ano_grafico.Ano == 2015].Sales_y.values, #valor de x
            align='center', height=hgt,label='2015',
             color='#00c698'
        )

for i in range(0,qtd_itens):
            ax.annotate('{: ,.1f}k'.format(itens_ano_grafico[itens_ano_grafico.Ano == 2018].Sales_y.values[i]/1000), 
                        (itens_ano_grafico[itens_ano_grafico.Ano == 2018].Sales_y.values[i], i - hgt-hgt/2 ),
                        ha="center", 
                        va="top",
                        xytext=(20,5), 
                        textcoords="offset points", 
                        color="#0059c0",
                        fontweight="bold")
            
ax.yaxis.set_ticks(np.arange(0,qtd_itens))
ax.set_yticklabels(top_n_itens["Product Name"])
ax.tick_params(axis='y', labelsize=10)
ax.invert_yaxis()
#ax.set_xticks(np.arange(0,45000, 5000))
ax.xaxis.set_visible(False)
ax.spines.top.set_visible(False)
ax.spines.right.set_visible(False) 
ax.spines.bottom.set_visible(False) 

plt.legend()
plt.show()

# %% [markdown]
# ### Organizando as perguntas/respostas

# %%
fig, ax = plt.subplots(figsize=(9,6))

soma_ano = base.groupby("Ano")["Sales"].sum()

ax.bar(soma_ano.index , soma_ano.values, linewidth=2, color="#84ba5b");
ax.set_title("VENDAS POR ANO",
             fontsize= 14,
             fontweight= "bold",
             color= "#84ba5b");
ax.xaxis.set_ticks([2015,2016,2017,2018]);
ax.tick_params(axis='x', labelsize=12)

for i in range(len(soma_ano.index)):
            ax.annotate('{: ,.0f}'.format(soma_ano.values[i]), (soma_ano.index[i], soma_ano.values[i]),ha="center", xytext=(0,7), textcoords="offset points", fontweight="bold")
ax.yaxis.set_visible(False)
ax.spines.left.set_visible(False)
ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)


plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,4))
w = 0.2
ax.bar(soma_mes[soma_mes.Ano == 2015].Mes.values -w-w/2, soma_mes[soma_mes.Ano == 2015].Sales.values,
                                color="#00c698", label='2015',width=w )
ax.bar(soma_mes[soma_mes.Ano == 2016].Mes.values-w/2 , soma_mes[soma_mes.Ano == 2016].Sales.values,
                                color='#00a9b5', label='2016',width=w)
ax.bar(soma_mes[soma_mes.Ano == 2017].Mes.values+w/2 , soma_mes[soma_mes.Ano == 2017].Sales.values,
                                color="#008ac5", label='2017',width=w )
ax.bar(soma_mes[soma_mes.Ano == 2018].Mes.values+w+w/2 , soma_mes[soma_mes.Ano == 2018].Sales.values,
                                color="#0069c0", label="2018",width=w )
ax.legend()
for i in range(0,12):
            ax.annotate('{: ,.0f}k'.format(soma_mes[soma_mes.Ano == 2018].Sales.values[i]/1000), 
                        (soma_mes[soma_mes.Ano == 2018].Mes.values[i]+w+w/2, soma_mes[soma_mes.Ano == 2018].Sales.values[i]),
                        ha="center", 
                        xytext=(3,5), 
                        textcoords="offset points", 
                        color="#0069c0",
                        fontweight="bold")
ax.set_yticks(np.array([0, 100000]))
ax.yaxis.set_visible(False)
ax.spines.top.set_visible(False)
ax.spines.right.set_visible(False)
ax.spines.left.set_visible(False) 
ax.xaxis.set_ticks(np.arange(1,13))
ax.set_xticklabels(['Jan','Fev','Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez'])
ax.set_title("VENDAS POR MÊS",
             fontsize= 14,
             fontweight= "bold",
             color= "#00b247");
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,4))
w = 0.2
ax.bar(categoria[categoria.Category == 'Furniture'].Ano.values-w, 
       categoria[categoria.Category == 'Furniture'].Sales.values,
                                color="#00c698", label='Furniture',width=w )
ax.bar(categoria[categoria.Category == 'Office Supplies'].Ano.values, 
       categoria[categoria.Category == 'Office Supplies'].Sales.values,
                                color="#00a9b5", label='Office Supplies',width=w )
ax.bar(categoria[categoria.Category == 'Technology'].Ano.values+w, 
       categoria[categoria.Category == 'Technology'].Sales.values,
                                color="#008ac5", label='Technology',width=w )

for i in range(0,4):
            ax.annotate('{: ,.0f}k'.format(categoria[categoria.Category == 'Furniture'].Sales.values[i]/1000), 
                        (categoria[categoria.Category == 'Furniture'].Ano.values[i]-w, categoria[categoria.Category == 'Furniture'].Sales.values[i]),
                        ha="center", 
                        xytext=(0,5), 
                        textcoords="offset points", 
                        color="#00c698",
                        fontweight="bold")
            ax.annotate('{: ,.0f}k'.format(categoria[categoria.Category == 'Office Supplies'].Sales.values[i]/1000), 
                        (categoria[categoria.Category == 'Office Supplies'].Ano.values[i], categoria[categoria.Category == 'Office Supplies'].Sales.values[i]),
                        ha="center", 
                        xytext=(0,5), 
                        textcoords="offset points", 
                        color="#00c698",
                        fontweight="bold")
            ax.annotate('{: ,.0f}k'.format(categoria[categoria.Category == 'Technology'].Sales.values[i]/1000), 
                        (categoria[categoria.Category == 'Technology'].Ano.values[i]+w, categoria[categoria.Category == 'Technology'].Sales.values[i]),
                        ha="center", 
                        xytext=(0,5), 
                        textcoords="offset points", 
                        color="#00c698",
                        fontweight="bold")
            
ax.set_yticks(np.array([0,350000]))
ax.yaxis.set_visible(False)
ax.set_title("VENDAS POR ANO DE CADA CATEGORIA",
             fontsize= 14,
             fontweight= "bold",
             color= "#00b247");

ax.spines.top.set_visible(False)
ax.spines.right.set_visible(False)
ax.spines.left.set_visible(False) 
ax.xaxis.set_ticks([2015,2016,2017,2018]);
ax.tick_params(axis='x', labelsize=10)

ax.legend()
plt.show()

# %%
fig, ax =plt.subplots(figsize=(10,9))

ax.barh(top_n_itens['Product Name'].values, #valor de y
            top_n_itens['Sales'].values,
            align='center'
        )
for i in range(0,n):
            ax.annotate('{: ,.0f}k'.format(top_n_itens['Sales'].values[i]/1000), 
                        (top_n_itens['Sales'].values[i], i ),
                        ha="center", 
                        va="top",
                        xytext=(-15,5), 
                        textcoords="offset points", 
                        color="#fff",
                        fontweight="bold")
            
ax.spines.top.set_visible(False)
ax.spines.right.set_visible(False)
ax.spines.left.set_visible(False) 
ax.spines.bottom.set_visible(False) 
ax.xaxis.set_visible(False)
ax.set_xticks(np.array([0,65000]))
ax.set_title("TOP 10 ITENS DE TODOS OS TEMPOS",
             fontsize= 14,
             fontweight= "bold",
             color= "#00b247");
ax.invert_yaxis()

# %%
fig, ax =plt.subplots(figsize=(10,9))
#itens_ano_grafico[itens_ano_grafico.Ano == 2018]['Product Name'].values
# itens_ano_grafico[itens_ano_grafico.Ano == 2018].Sales_y.values - vendas ano a ano de cade item
hgt = 0.2
qtd_itens = len(top_n_itens)
ax.barh(np.arange(0, qtd_itens)-hgt-hgt/2, #valor de y
            itens_ano_grafico[itens_ano_grafico.Ano == 2018].Sales_y.values, #valor de x
            align='center', height=hgt,label='2018',
            color='#0059c0'
        )
ax.barh(np.arange(0, qtd_itens)-hgt/2, #valor de y
            itens_ano_grafico[itens_ano_grafico.Ano == 2017].Sales_y.values, #valor de x
            align='center', height=hgt,label='2017',
             color='#008ac5'
        )
ax.barh(np.arange(0, qtd_itens)+hgt/2, #valor de y
            itens_ano_grafico[itens_ano_grafico.Ano == 2016].Sales_y.values, #valor de x
            align='center', height=hgt,label='2016',
            color='#00a9b5'
        )
ax.barh(np.arange(0, qtd_itens)+hgt+hgt/2, #valor de y
            itens_ano_grafico[itens_ano_grafico.Ano == 2015].Sales_y.values, #valor de x
            align='center', height=hgt,label='2015',
             color='#00c698'
        )

for i in range(0,qtd_itens):
            ax.annotate('{: ,.1f}k'.format(itens_ano_grafico[itens_ano_grafico.Ano == 2018].Sales_y.values[i]/1000), 
                        (itens_ano_grafico[itens_ano_grafico.Ano == 2018].Sales_y.values[i], i - hgt-hgt/2 ),
                        ha="center", 
                        va="top",
                        xytext=(20,5), 
                        textcoords="offset points", 
                        color="#0059c0",
                        fontweight="bold")
            
ax.yaxis.set_ticks(np.arange(0,qtd_itens))
ax.set_yticklabels(top_n_itens["Product Name"])
ax.tick_params(axis='y', labelsize=10)
ax.invert_yaxis()
#ax.set_xticks(np.arange(0,45000, 5000))
ax.xaxis.set_visible(False)
ax.spines.top.set_visible(False)
ax.spines.right.set_visible(False) 
ax.spines.bottom.set_visible(False) 
ax.set_title("ITENS X ANOS",
             fontsize= 14,
             fontweight= "bold",
             color= "#00b247");
plt.legend()
plt.show()
